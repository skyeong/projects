# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

x = tf.placeholder(tf.float32, [None, 5])
w = tf.Variable(tf.zeros([5,1]))
y = tf.matmul(x,w)
t = tf.placeholder(tf.float32, [None, 1])

# Define loss function
loss = tf.reduce_sum(tf.square(y-t))
train_step = tf.train.AdamOptimizer().minimize(loss)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

train_t = np.array([5.2, 5.7, 8.6, 14.9, 18.2, 20.4, 25.5, 26.4, 22.8, 17.5, 11.1, 6.6])
train_t = train_t.reshape([12,1])

train_x = np.zeros([12,5])
for row, month in enumerate(range(1,13)):
    for col, n in enumerate(range(0,5)):
        print(row, month, col, n)
        train_x[row][col] = month**n
        
        
i = 0
for _ in range(100000):
    i += 1
    sess.run(train_step, feed_dict={x:train_x, t:train_t})
    if i%1000 == 0:
        loss_val = sess.run(loss, feed_dict={x:train_x, t:train_t})
        print('Step: %d, Loss:%f' % (i, loss_val))

# %%
# Out:
# 0 1 0 0
# 0 1 1 1
# 0 1 2 2
# 0 1 3 3
# 0 1 4 4
# 1 2 0 0
# 1 2 1 1
# 1 2 2 2
# 1 2 3 3
# 1 2 4 4
# 2 3 0 0
# 2 3 1 1
# 2 3 2 2
# 2 3 3 3
# 2 3 4 4
# 3 4 0 0
# 3 4 1 1
# 3 4 2 2
# 3 4 3 3
# 3 4 4 4
# 4 5 0 0
# 4 5 1 1
# 4 5 2 2
# 4 5 3 3
# 4 5 4 4
# 5 6 0 0
# 5 6 1 1
# 5 6 2 2
# 5 6 3 3
# 5 6 4 4
# 6 7 0 0
# 6 7 1 1
# 6 7 2 2
# 6 7 3 3
# 6 7 4 4
# 7 8 0 0
# 7 8 1 1
# 7 8 2 2
# 7 8 3 3
# 7 8 4 4
# 8 9 0 0
# 8 9 1 1
# 8 9 2 2
# 8 9 3 3
# 8 9 4 4
# 9 10 0 0
# 9 10 1 1
# 9 10 2 2
# 9 10 3 3
# 9 10 4 4
# 10 11 0 0
# 10 11 1 1
# 10 11 2 2
# 10 11 3 3
# 10 11 4 4
# 11 12 0 0
# 11 12 1 1
# 11 12 2 2
# 11 12 3 3
# 11 12 4 4

# %%
# Out:
# Step: 1000, Loss:107.579964
# Step: 2000, Loss:61.405148
# Step: 3000, Loss:37.144585
# Step: 4000, Loss:52.269978
# Step: 5000, Loss:33.045536
# Step: 6000, Loss:32.350376
# Step: 7000, Loss:31.822300
# Step: 8000, Loss:31.349792
# Step: 9000, Loss:31.014380
# Step: 10000, Loss:35.400208
# Step: 11000, Loss:30.588045
# Step: 12000, Loss:30.323301
# Step: 13000, Loss:30.152081
# Step: 14000, Loss:30.351875
# Step: 15000, Loss:29.842335
# Step: 16000, Loss:29.698570
# Step: 17000, Loss:30.745583
# Step: 18000, Loss:31.400488
# Step: 19000, Loss:29.290693
# Step: 20000, Loss:29.157623
# Step: 21000, Loss:29.027140
# Step: 22000, Loss:34.142921
# Step: 23000, Loss:28.778376
# Step: 24000, Loss:28.642723
# Step: 25000, Loss:30.520748
# Step: 26000, Loss:28.391981
# Step: 27000, Loss:28.268099
# Step: 28000, Loss:28.145079
# Step: 29000, Loss:28.022751
# Step: 30000, Loss:27.901966
# Step: 31000, Loss:27.781324
# Step: 32000, Loss:27.663025
# Step: 33000, Loss:41.333923
# Step: 34000, Loss:27.427692
# Step: 35000, Loss:27.318815
# Step: 36000, Loss:27.195251
# Step: 37000, Loss:27.083935
# Step: 38000, Loss:26.973206
# Step: 39000, Loss:27.663746
# Step: 40000, Loss:26.742168
# Step: 41000, Loss:26.631557
# Step: 42000, Loss:26.521011
# Step: 43000, Loss:26.411234
# Step: 44000, Loss:26.302591
# Step: 45000, Loss:26.194126
# Step: 46000, Loss:26.146027
# Step: 47000, Loss:26.296135
# Step: 48000, Loss:25.874981
# Step: 49000, Loss:25.792316
# Step: 50000, Loss:25.666328
# Step: 51000, Loss:25.562847
# Step: 52000, Loss:25.546352
# Step: 53000, Loss:25.359406
# Step: 54000, Loss:25.258514
# Step: 55000, Loss:26.594181
# Step: 56000, Loss:25.068464
# Step: 57000, Loss:24.960739
# Step: 58000, Loss:24.869057
# Step: 59000, Loss:24.766474
# Step: 60000, Loss:24.670135
# Step: 61000, Loss:24.574524
# Step: 62000, Loss:24.479927
# Step: 63000, Loss:24.463629
# Step: 64000, Loss:24.292877
# Step: 65000, Loss:24.200069
# Step: 66000, Loss:24.108292
# Step: 67000, Loss:24.016905
# Step: 68000, Loss:23.927635
# Step: 69000, Loss:23.838539
# Step: 70000, Loss:23.872911
# Step: 71000, Loss:23.659136
# Step: 72000, Loss:23.571224
# Step: 73000, Loss:23.484266
# Step: 74000, Loss:25.885017
# Step: 75000, Loss:23.311684
# Step: 76000, Loss:23.226204
# Step: 77000, Loss:23.141886
# Step: 78000, Loss:23.057896
# Step: 79000, Loss:22.974419
# Step: 80000, Loss:22.892101
# Step: 81000, Loss:22.817982
# Step: 82000, Loss:23.907080
# Step: 83000, Loss:50.575752
# Step: 84000, Loss:22.567427
# Step: 85000, Loss:22.488243
# Step: 86000, Loss:22.410259
# Step: 87000, Loss:22.331444
# Step: 88000, Loss:22.253283
# Step: 89000, Loss:22.176279
# Step: 90000, Loss:22.102398
# Step: 91000, Loss:22.023756
# Step: 92000, Loss:21.948624
# Step: 93000, Loss:21.879429
# Step: 94000, Loss:27.233679
# Step: 95000, Loss:34.056129
# Step: 96000, Loss:21.652599
# Step: 97000, Loss:21.580166
# Step: 98000, Loss:21.598476
# Step: 99000, Loss:22.416885
# Step: 100000, Loss:21.366203
